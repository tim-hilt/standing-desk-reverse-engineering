# %% [markdown]
# # Imports / Types

# %%
from collections import namedtuple, Counter, OrderedDict
from pprint import pprint

# %%
SpiFrame = namedtuple("SpiFrame", ["name", "ftype", "start_time", "duration", "mosi", "miso"])

# %% [markdown]
# # Functions

# %%
def parse_frames(lines: list[str]) -> list[SpiFrame]:
    frames: list[SpiFrame] = []

    for frame in lines[1:]:
        name, ftype, start_time, duration, mosi, miso = frame.split(",")
        frames.append(SpiFrame(name, ftype, start_time, duration, mosi, miso))
    return frames

def pack_4(frames: list[SpiFrame]) -> OrderedDict[str, str]:
    data: OrderedDict[str, str] = OrderedDict()

    i = 0
    while i < len(frames):
        frame = frames[i]
        if frame.ftype == '"result"' and i+3 < len(frames):
            data[frame.start_time] = f"{frame.miso} {frames[i+1].miso} {frames[i+2].miso} {frames[i+3].miso}"
            i += 3
        i += 1
    return data

def count_unique_frames(data: OrderedDict[str, str]):
    cnt = Counter()
    for _, miso in data.items():
        cnt[miso] += 1
    pprint(cnt)

# TODO: Make this a bit more general, so that hex, dec and bin can
#   be printed without having to call reverse
def reverse_bits(h: str) -> tuple[int, str, str]:
    reversed = bin(int(h, 16))[2:].zfill(8)[::-1]
    decimal = int(reversed, 2)
    hexadecimal = f"0x{decimal:02X}"
    return decimal, hexadecimal, reversed

def print_reversed(frames: list[str]):
    print("original data\t\treversed decimal\treversed hexadecimal\treversed binary")
    for frame in frames:
        packages = frame.split()
        decimals, hexadecimals, binaries = zip(*[reverse_bits(package) for package in packages])
        print(f"{frame}\t{' '.join(str(d) for d in decimals)}\t\t{' '.join(list(hexadecimals))}\t{' '.join(list(binaries))}")

def print_data_table(frames: list[str]):
    print("original data\t\tbinary encoding\t\t\t\tdecimal encoding")
    for frame in frames:
        hex_pieces = frame.split()
        frame_decimal = [int(h, 16) for h in hex_pieces]
        frame_binary = [bin(d)[2:].zfill(8) for d in frame_decimal]
        print(f"{frame}\t{' '.join(frame_binary)}\t{' '.join(str(d) for d in frame_decimal)}")

# %% [markdown]
# ---
#
# # Data Analysis

# %%
with open("data/button-2-drive-up.csv", "r", encoding="utf-8") as f:
    lines = f.read().split()

# %%
len(lines)
# Out:
# 18505

# %%
lines[0]
# Out:
# 'name,type,start_time,duration,"mosi","miso"'

# %%
frames = parse_frames(lines)
len(frames)
# Out:
# 18504

# %%
frames
# Out:
# [SpiFrame(name='"SPI"', ftype='"enable"', start_time='0.004146276', duration='4e-09', mosi='', miso=''),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.0041478', duration='0.000299952', mosi='0x00', miso='0xA5'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.004494628', duration='0.000288868', mosi='0x00', miso='0x85'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.004809908', duration='0.00025998', mosi='0x00', miso='0x00'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.005096304', duration='0.000284956', mosi='0x00', miso='0x7F'),
#  SpiFrame(name='"SPI"', ftype='"disable"', start_time='0.005445488', duration='4e-09', mosi='', miso=''),
#  SpiFrame(name='"SPI"', ftype='"enable"', start_time='0.009134644', duration='4e-09', mosi='', miso=''),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.009136172', duration='0.00032598', mosi='0x00', miso='0xA5'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.009509036', duration='0.000288916', mosi='0x00', miso='0x85'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.009824372', duration='0.000259984', mosi='0x00', miso='0x00'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.010110772', duration='0.000284964', mosi='0x00', miso='0x7F'),
#  SpiFrame(name='"SPI"', ftype='"disable"', start_time='0.010459968', duration='4e-09', mosi='', miso=''),
#  SpiFrame(name='"SPI"', ftype='"enable"', start_time='0.014122704', duration='4e-09', mosi='', miso=''),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.014124228', duration='0.000325988', mosi='0x00', miso='0xA5'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.0144971', duration='0.000288904', mosi='0x00', miso='0x85'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.014812424', duration='0.000260004', mosi='0x00', miso='0x00'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.015098844', duration='0.000284804', mosi='0x00', miso='0x7F'),
#  SpiFrame(name='"SPI"', ftype='"disable"', start_time='0.01544788', duration='4e-09', mosi='', miso=''),
#  SpiFrame(name='"SPI"', ftype='"enable"', start_time='0.019110676', duration='4e-09', mosi='', miso=''),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.0191122', duration='0.000325988', mosi='0x00', miso='0xA5'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.019485064', duration='0.000262908', mosi='0x00', miso='0x85'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.019774392', duration='0.000286012', mosi='0x00', miso='0x00'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.02008682', duration='0.00028498', mosi='0x00', miso='0x7F'),
#  SpiFrame(name='"SPI"', ftype='"disable"', start_time='0.02043604', duration='4e-09', mosi='', miso=''),
#  SpiFrame(name='"SPI"', ftype='"enable"', start_time='0.024099152', duration='4e-09', mosi='', miso=''),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.02410068', duration='0.000325832', mosi='0x00', miso='0xA5'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.024473392', duration='0.000262896', mosi='0x00', miso='0x85'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.024762704', duration='0.000286044', mosi='0x00', miso='0x00'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.025075164', duration='0.000258992', mosi='0x00', miso='0x7F'),
#  SpiFrame(name='"SPI"', ftype='"disable"', start_time='0.02542432', duration='4e-09', mosi='', miso=''),
#  SpiFrame(name='"SPI"', ftype='"enable"', start_time='0.02908776', duration='4e-09', mosi='', miso=''),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.029089288', duration='0.000299984', mosi='0x00', miso='0xA5'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.029462', duration='0.0002629', mosi='0x00', miso='0x85'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.029751324', duration='0.000286028', mosi='0x00', miso='0x00'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.030063772', duration='0.000258984', mosi='0x00', miso='0x7F'),
#  SpiFrame(name='"SPI"', ftype='"disable"', start_time='0.030387', duration='4e-09', mosi='', miso=''),
#  SpiFrame(name='"SPI"', ftype='"enable"', start_time='0.034075856', duration='4e-09', mosi='', miso=''),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.03407738', duration='0.000299992', mosi='0x00', miso='0xA5'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.034424252', duration='0.000288916', mosi='0x00', miso='0x85'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.034739584', duration='0.00028602', mosi='0x00', miso='0x00'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.03505202', duration='0.00025898', mosi='0x00', miso='0x7F'),
#  SpiFrame(name='"SPI"', ftype='"disable"', start_time='0.03537524', duration='4e-09', mosi='', miso=''),
#  SpiFrame(name='"SPI"', ftype='"enable"', start_time='0.039064144', duration='4e-09', mosi='', miso=''),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.039065668', duration='0.00029998', mosi='0x00', miso='0xA5'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.03941252', duration='0.000288736', mosi='0x00', miso='0x85'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.039727668', duration='0.000260004', mosi='0x00', miso='0x00'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.040014088', duration='0.000284828', mosi='0x00', miso='0x7F'),
#  SpiFrame(name='"SPI"', ftype='"disable"', start_time='0.040363152', duration='4e-09', mosi='', miso=''),
#  SpiFrame(name='"SPI"', ftype='"enable"', start_time='0.044052656', duration='4e-09', mosi='', miso=''),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.04405418', duration='0.000326008', mosi='0x00', miso='0xA5'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.044427072', duration='0.000288916', mosi='0x00', miso='0x85'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.044742404', duration='0.000260024', mosi='0x00', miso='0x00'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.045028848', duration='0.000284996', mosi='0x00', miso='0x7F'),
#  SpiFrame(name='"SPI"', ftype='"disable"', start_time='0.045378092', duration='4e-09', mosi='', miso=''),
#  SpiFrame(name='"SPI"', ftype='"enable"', start_time='0.049041344', duration='4e-09', mosi='', miso=''),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.049042868', duration='0.000325992', mosi='0x00', miso='0xA5'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.049415744', duration='0.000288912', mosi='0x00', miso='0x85'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.049731076', duration='0.000260036', mosi='0x00', miso='0x00'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.050017532', duration='0.000284836', mosi='0x00', miso='0x7F'),
#  SpiFrame(name='"SPI"', ftype='"disable"', start_time='0.050366604', duration='4e-09', mosi='', miso=''),
#  SpiFrame(name='"SPI"', ftype='"enable"', start_time='0.054029692', duration='4e-09', mosi='', miso=''),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.05403122', duration='0.000326016', mosi='0x00', miso='0xA5'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.054404116', duration='0.0002629', mosi='0x00', miso='0x85'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.054693432', duration='0.000286024', mosi='0x00', miso='0x00'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.055005872', duration='0.000284992', mosi='0x00', miso='0x7F'),
#  SpiFrame(name='"SPI"', ftype='"disable"', start_time='0.055355112', duration='4e-09', mosi='', miso=''),
#  SpiFrame(name='"SPI"', ftype='"enable"', start_time='0.059018164', duration='4e-09', mosi='', miso=''),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.059019692', duration='0.000325908', mosi='0x00', miso='0xA5'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.05939248', duration='0.000262908', mosi='0x00', miso='0x85'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.059681804', duration='0.000286008', mosi='0x00', miso='0x00'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.059994228', duration='0.000258988', mosi='0x00', miso='0x7F'),
#  SpiFrame(name='"SPI"', ftype='"disable"', start_time='0.0603433', duration='4e-09', mosi='', miso=''),
#  SpiFrame(name='"SPI"', ftype='"enable"', start_time='0.064006812', duration='4e-09', mosi='', miso=''),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.06400834', duration='0.00029996', mosi='0x00', miso='0xA5'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.06438118', duration='0.000262888', mosi='0x00', miso='0x85'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.064670484', duration='0.000286', mosi='0x00', miso='0x00'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.0649829', duration='0.000258988', mosi='0x00', miso='0x7F'),
#  SpiFrame(name='"SPI"', ftype='"disable"', start_time='0.065306128', duration='4e-09', mosi='', miso=''),
#  SpiFrame(name='"SPI"', ftype='"enable"', start_time='0.06899494', duration='4e-09', mosi='', miso=''),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.068996464', duration='0.000299936', mosi='0x00', miso='0xA5'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.069343272', duration='0.000288856', mosi='0x00', miso='0x85'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.069658548', duration='0.000285996', mosi='0x00', miso='0x00'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.06997096', duration='0.00025896', mosi='0x00', miso='0x7F'),
#  SpiFrame(name='"SPI"', ftype='"disable"', start_time='0.070294152', duration='4e-09', mosi='', miso=''),
#  SpiFrame(name='"SPI"', ftype='"enable"', start_time='0.073983052', duration='4.00000002e-09', mosi='', miso=''),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.073984576', duration='0.00029996', mosi='0x00', miso='0xA5'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.074331412', duration='0.000288896', mosi='0x00', miso='0x85'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.074646728', duration='0.000260036', mosi='0x00', miso='0x00'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.07493318', duration='0.000284868', mosi='0x00', miso='0x7F'),
#  SpiFrame(name='"SPI"', ftype='"disable"', start_time='0.075282292', duration='4e-09', mosi='', miso=''),
#  SpiFrame(name='"SPI"', ftype='"enable"', start_time='0.078971332', duration='4e-09', mosi='', miso=''),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.07897286', duration='0.000325984', mosi='0x00', miso='0xA5'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.079345724', duration='0.000288904', mosi='0x00', miso='0x85'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.079661048', duration='0.000260004', mosi='0x00', miso='0x00'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.079947468', duration='0.000284964', mosi='0x00', miso='0x7F'),
#  SpiFrame(name='"SPI"', ftype='"disable"', start_time='0.080296668', duration='4e-09', mosi='', miso=''),
#  SpiFrame(name='"SPI"', ftype='"enable"', start_time='0.08395936', duration='3.99999999e-09', mosi='', miso=''),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.083960884', duration='0.000326004', mosi='0x00', miso='0xA5'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.084333768', duration='0.000288916', mosi='0x00', miso='0x85'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.084649104', duration='0.000260032', mosi='0x00', miso='0x00'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.084935556', duration='0.000284896', mosi='0x00', miso='0x7F'),
#  SpiFrame(name='"SPI"', ftype='"disable"', start_time='0.085284684', duration='4e-09', mosi='', miso=''),
#  SpiFrame(name='"SPI"', ftype='"enable"', start_time='0.088947768', duration='4e-09', mosi='', miso=''),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.088949296', duration='0.000325832', mosi='0x00', miso='0xA5'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.089322012', duration='0.000262912', mosi='0x00', miso='0x85'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.089611344', duration='0.000286016', mosi='0x00', miso='0x00'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.089923772', duration='0.00028496', mosi='0x00', miso='0x7F'),
#  SpiFrame(name='"SPI"', ftype='"disable"', start_time='0.090272976', duration='4e-09', mosi='', miso=''),
#  SpiFrame(name='"SPI"', ftype='"enable"', start_time='0.093936108', duration='4e-09', mosi='', miso=''),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.093937632', duration='0.000325804', mosi='0x00', miso='0xA5'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.09431032', duration='0.000262916', mosi='0x00', miso='0x85'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.094599652', duration='0.000285872', mosi='0x00', miso='0x00'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.09491194', duration='0.00025898', mosi='0x00', miso='0x7F'),
#  SpiFrame(name='"SPI"', ftype='"disable"', start_time='0.095261168', duration='4e-09', mosi='', miso=''),
#  SpiFrame(name='"SPI"', ftype='"enable"', start_time='0.09892426', duration='3.99999999e-09', mosi='', miso=''),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.098925784', duration='0.000299968', mosi='0x00', miso='0xA5'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.099298628', duration='0.00026288', mosi='0x00', miso='0x85'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.099587928', duration='0.000286004', mosi='0x00', miso='0x00'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.099900344', duration='0.000258972', mosi='0x00', miso='0x7F'),
#  SpiFrame(name='"SPI"', ftype='"disable"', start_time='0.100223548', duration='4e-09', mosi='', miso=''),
#  SpiFrame(name='"SPI"', ftype='"enable"', start_time='0.103912588', duration='4e-09', mosi='', miso=''),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.103914112', duration='0.00029996', mosi='0x00', miso='0xA5'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.104260948', duration='0.00028882', mosi='0x00', miso='0x85'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.104576192', duration='0.000286036', mosi='0x00', miso='0x00'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.104888648', duration='0.000259', mosi='0x00', miso='0x7F'),
#  SpiFrame(name='"SPI"', ftype='"disable"', start_time='0.105211896', duration='4e-09', mosi='', miso=''),
#  SpiFrame(name='"SPI"', ftype='"enable"', start_time='0.108901008', duration='4.00000002e-09', mosi='', miso=''),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.108902532', duration='0.00029994', mosi='0x00', miso='0xA5'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.109249348', duration='0.000288868', mosi='0x00', miso='0x85'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.109564632', duration='0.000259992', mosi='0x00', miso='0x00'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.109851036', duration='0.000284944', mosi='0x00', miso='0x7F'),
#  SpiFrame(name='"SPI"', ftype='"disable"', start_time='0.110200212', duration='3.99999999e-09', mosi='', miso=''),
#  SpiFrame(name='"SPI"', ftype='"enable"', start_time='0.113889092', duration='4e-09', mosi='', miso=''),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.113890616', duration='0.00032596', mosi='0x00', miso='0xA5'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.114263452', duration='0.000288888', mosi='0x00', miso='0x85'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.114578756', duration='0.000260024', mosi='0x00', miso='0x00'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.1148652', duration='0.000284996', mosi='0x00', miso='0x7F'),
#  SpiFrame(name='"SPI"', ftype='"disable"', start_time='0.115214428', duration='4e-09', mosi='', miso=''),
#  SpiFrame(name='"SPI"', ftype='"enable"', start_time='0.118877788', duration='4e-09', mosi='', miso=''),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.118879316', duration='0.00032584', mosi='0x00', miso='0xA5'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.119252036', duration='0.00028876', mosi='0x00', miso='0x85'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.119567216', duration='0.00026006', mosi='0x00', miso='0x00'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.119853692', duration='0.000284984', mosi='0x00', miso='0x7F'),
#  SpiFrame(name='"SPI"', ftype='"disable"', start_time='0.120202912', duration='4e-09', mosi='', miso=''),
#  SpiFrame(name='"SPI"', ftype='"enable"', start_time='0.123865872', duration='4e-09', mosi='', miso=''),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.123867396', duration='0.000325992', mosi='0x00', miso='0xA5'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.124240272', duration='0.0002629', mosi='0x00', miso='0x85'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.124555592', duration='0.000260012', mosi='0x00', miso='0x00'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.124842024', duration='0.00028484', mosi='0x00', miso='0x7F'),
#  SpiFrame(name='"SPI"', ftype='"disable"', start_time='0.125191104', duration='4e-09', mosi='', miso=''),
#  SpiFrame(name='"SPI"', ftype='"enable"', start_time='0.12885456', duration='3.99999999e-09', mosi='', miso=''),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.128856084', duration='0.000325996', mosi='0x00', miso='0xA5'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.12922896', duration='0.000262904', mosi='0x00', miso='0x85'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.129518284', duration='0.000286016', mosi='0x00', miso='0x00'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.129830716', duration='0.000258984', mosi='0x00', miso='0x7F'),
#  SpiFrame(name='"SPI"', ftype='"disable"', start_time='0.130179928', duration='4.00000002e-09', mosi='', miso=''),
#  SpiFrame(name='"SPI"', ftype='"enable"', start_time='0.133842592', duration='4.00000002e-09', mosi='', miso=''),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.133844116', duration='0.000325992', mosi='0x00', miso='0xA5'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.13421698', duration='0.000262908', mosi='0x00', miso='0x85'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.134506308', duration='0.000286036', mosi='0x00', miso='0x00'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.134818764', duration='0.000258988', mosi='0x00', miso='0x7F'),
#  SpiFrame(name='"SPI"', ftype='"disable"', start_time='0.135141992', duration='3.99999999e-09', mosi='', miso=''),
#  SpiFrame(name='"SPI"', ftype='"enable"', start_time='0.138830876', duration='3.99999999e-09', mosi='', miso=''),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.138832404', duration='0.00029996', mosi='0x00', miso='0xA5'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.13917924', duration='0.000288872', mosi='0x00', miso='0x85'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.139494528', duration='0.00028602', mosi='0x00', miso='0x00'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.139806964', duration='0.000258976', mosi='0x00', miso='0x7F'),
#  SpiFrame(name='"SPI"', ftype='"disable"', start_time='0.140130176', duration='3.99999999e-09', mosi='', miso=''),
#  SpiFrame(name='"SPI"', ftype='"enable"', start_time='0.14381898', duration='3.99999999e-09', mosi='', miso=''),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.143820504', duration='0.00030434', mosi='0x00', miso='0xA5'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.144171732', duration='0.000288916', mosi='0x00', miso='0x85'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.144487064', duration='0.00026002', mosi='0x00', miso='0x00'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.144799504', duration='0.000258988', mosi='0x00', miso='0x7F'),
#  SpiFrame(name='"SPI"', ftype='"disable"', start_time='0.145122736', duration='3.99999999e-09', mosi='', miso=''),
#  SpiFrame(name='"SPI"', ftype='"enable"', start_time='0.148807492', duration='3.99999999e-09', mosi='', miso=''),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.148809016', duration='0.000325972', mosi='0x00', miso='0xA5'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.149181864', duration='0.00028888', mosi='0x00', miso='0x85'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.14949716', duration='0.000260012', mosi='0x00', miso='0x00'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.149783588', duration='0.000284972', mosi='0x00', miso='0x7F'),
#  SpiFrame(name='"SPI"', ftype='"disable"', start_time='0.150132788', duration='4.00000002e-09', mosi='', miso=''),
#  SpiFrame(name='"SPI"', ftype='"enable"', start_time='0.153795432', duration='3.99999999e-09', mosi='', miso=''),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.153796956', duration='0.000325896', mosi='0x00', miso='0xA5'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.154169728', duration='0.000288708', mosi='0x00', miso='0x85'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.154484848', duration='0.000260004', mosi='0x00', miso='0x00'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.154771264', duration='0.000284964', mosi='0x00', miso='0x7F'),
#  SpiFrame(name='"SPI"', ftype='"disable"', start_time='0.155120464', duration='3.99999999e-09', mosi='', miso=''),
#  SpiFrame(name='"SPI"', ftype='"enable"', start_time='0.158783644', duration='3.99999999e-09', mosi='', miso=''),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.158785168', duration='0.000325944', mosi='0x00', miso='0xA5'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.159157988', duration='0.000262888', mosi='0x00', miso='0x85'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.159473212', duration='0.000259992', mosi='0x00', miso='0x00'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.15975962', duration='0.000284948', mosi='0x00', miso='0x7F'),
#  SpiFrame(name='"SPI"', ftype='"disable"', start_time='0.160108792', duration='3.99999999e-09', mosi='', miso=''),
#  SpiFrame(name='"SPI"', ftype='"enable"', start_time='0.163771616', duration='4.00000002e-09', mosi='', miso=''),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.16377314', duration='0.00032598', mosi='0x00', miso='0xA5'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.164146', duration='0.000262896', mosi='0x00', miso='0x85'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.164435316', duration='0.000285948', mosi='0x00', miso='0x00'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.164747684', duration='0.000285008', mosi='0x00', miso='0x7F'),
#  SpiFrame(name='"SPI"', ftype='"disable"', start_time='0.165096924', duration='3.99999999e-09', mosi='', miso=''),
#  SpiFrame(name='"SPI"', ftype='"enable"', start_time='0.168759924', duration='3.99999999e-09', mosi='', miso=''),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.168761452', duration='0.000325916', mosi='0x00', miso='0xA5'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.169134256', duration='0.000262916', mosi='0x00', miso='0x85'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.169423592', duration='0.000286028', mosi='0x00', miso='0x00'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.169736032', duration='0.000258984', mosi='0x00', miso='0x7F'),
#  SpiFrame(name='"SPI"', ftype='"disable"', start_time='0.170059256', duration='3.99999999e-09', mosi='', miso=''),
#  SpiFrame(name='"SPI"', ftype='"enable"', start_time='0.173748152', duration='4.00000002e-09', mosi='', miso=''),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.173749676', duration='0.000299976', mosi='0x00', miso='0xA5'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.174096532', duration='0.000288892', mosi='0x00', miso='0x85'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.17441184', duration='0.000285968', mosi='0x00', miso='0x00'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.17472422', duration='0.00025896', mosi='0x00', miso='0x7F'),
#  SpiFrame(name='"SPI"', ftype='"disable"', start_time='0.175047408', duration='4.00000002e-09', mosi='', miso=''),
#  SpiFrame(name='"SPI"', ftype='"enable"', start_time='0.178736548', duration='3.99999999e-09', mosi='', miso=''),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.178738072', duration='0.000299996', mosi='0x00', miso='0xA5'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.179084952', duration='0.000288916', mosi='0x00', miso='0x85'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.179400284', duration='0.000260004', mosi='0x00', miso='0x00'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.179712556', duration='0.000258988', mosi='0x00', miso='0x7F'),
#  SpiFrame(name='"SPI"', ftype='"disable"', start_time='0.180035784', duration='3.99999999e-09', mosi='', miso=''),
#  SpiFrame(name='"SPI"', ftype='"enable"', start_time='0.183724924', duration='3.99999999e-09', mosi='', miso=''),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.183752448', duration='0.000299988', mosi='0x00', miso='0xA5'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.184099316', duration='0.0002889', mosi='0x00', miso='0x85'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.184414636', duration='0.000260016', mosi='0x00', miso='0x00'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.184701072', duration='0.000284976', mosi='0x00', miso='0x7F'),
#  SpiFrame(name='"SPI"', ftype='"disable"', start_time='0.185050284', duration='3.99999999e-09', mosi='', miso=''),
#  SpiFrame(name='"SPI"', ftype='"enable"', start_time='0.188713232', duration='3.99999999e-09', mosi='', miso=''),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.18871476', duration='0.000325836', mosi='0x00', miso='0xA5'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.189087476', duration='0.000288744', mosi='0x00', miso='0x85'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.189402636', duration='0.000259996', mosi='0x00', miso='0x00'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.189689048', duration='0.00028496', mosi='0x00', miso='0x7F'),
#  SpiFrame(name='"SPI"', ftype='"disable"', start_time='0.190038236', duration='3.99999999e-09', mosi='', miso=''),
#  SpiFrame(name='"SPI"', ftype='"enable"', start_time='0.193701312', duration='4.00000005e-09', mosi='', miso=''),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.193702836', duration='0.000325784', mosi='0x00', miso='0xA5'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.194075492', duration='0.000262884', mosi='0x00', miso='0x85'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.194390788', duration='0.000259984', mosi='0x00', miso='0x00'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.194677184', duration='0.00028494', mosi='0x00', miso='0x7F'),
#  SpiFrame(name='"SPI"', ftype='"disable"', start_time='0.195026352', duration='4.00000005e-09', mosi='', miso=''),
#  SpiFrame(name='"SPI"', ftype='"enable"', start_time='0.198689332', duration='3.99999999e-09', mosi='', miso=''),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.19869086', duration='0.000325904', mosi='0x00', miso='0xA5'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.199063644', duration='0.0002629', mosi='0x00', miso='0x85'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.199352964', duration='0.000286028', mosi='0x00', miso='0x00'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.199665412', duration='0.000285', mosi='0x00', miso='0x7F'),
#  SpiFrame(name='"SPI"', ftype='"disable"', start_time='0.20001464', duration='4.00000002e-09', mosi='', miso=''),
#  SpiFrame(name='"SPI"', ftype='"enable"', start_time='0.203677456', duration='3.99999999e-09', mosi='', miso=''),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.20367898', duration='0.00032598', mosi='0x00', miso='0xA5'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.204051836', duration='0.000262912', mosi='0x00', miso='0x85'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.204341164', duration='0.000285884', mosi='0x00', miso='0x00'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.204653464', duration='0.000258996', mosi='0x00', miso='0x7F'),
#  SpiFrame(name='"SPI"', ftype='"disable"', start_time='0.204976692', duration='4.00000002e-09', mosi='', miso=''),
#  SpiFrame(name='"SPI"', ftype='"enable"', start_time='0.208665756', duration='3.99999999e-09', mosi='', miso=''),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.20866728', duration='0.000299996', mosi='0x00', miso='0xA5'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.209014156', duration='0.000288756', mosi='0x00', miso='0x85'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.209329328', duration='0.000286', mosi='0x00', miso='0x00'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.209641744', duration='0.00025898', mosi='0x00', miso='0x7F'),
#  SpiFrame(name='"SPI"', ftype='"disable"', start_time='0.209964956', duration='4.00000002e-09', mosi='', miso=''),
#  SpiFrame(name='"SPI"', ftype='"enable"', start_time='0.213654016', duration='3.99999999e-09', mosi='', miso=''),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.21365554', duration='0.000299984', mosi='0x00', miso='0xA5'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.214002404', duration='0.00028892', mosi='0x00', miso='0x85'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.214317744', duration='0.000260024', mosi='0x00', miso='0x00'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.214630192', duration='0.000259008', mosi='0x00', miso='0x7F'),
#  SpiFrame(name='"SPI"', ftype='"disable"', start_time='0.21495344', duration='3.99999999e-09', mosi='', miso=''),
#  SpiFrame(name='"SPI"', ftype='"enable"', start_time='0.218668604', duration='3.99999999e-09', mosi='', miso=''),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.218670128', duration='0.000299976', mosi='0x00', miso='0xA5'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.21901698', duration='0.000288884', mosi='0x00', miso='0x85'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.219332276', duration='0.000264384', mosi='0x00', miso='0x00'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.219623076', duration='0.00028498', mosi='0x00', miso='0x7F'),
#  SpiFrame(name='"SPI"', ftype='"disable"', start_time='0.219972296', duration='4.00000002e-09', mosi='', miso=''),
#  SpiFrame(name='"SPI"', ftype='"enable"', start_time='0.223631192', duration='4.00000002e-09', mosi='', miso=''),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.22363272', duration='0.00032596', mosi='0x00', miso='0xA5'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.22400556', duration='0.000288728', mosi='0x00', miso='0x85'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.224320704', duration='0.000259984', mosi='0x00', miso='0x00'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.224607104', duration='0.000284948', mosi='0x00', miso='0x7F'),
#  SpiFrame(name='"SPI"', ftype='"disable"', start_time='0.224956284', duration='3.99999999e-09', mosi='', miso=''),
#  SpiFrame(name='"SPI"', ftype='"enable"', start_time='0.228619212', duration='4.00000002e-09', mosi='', miso=''),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.228620736', duration='0.000325936', mosi='0x00', miso='0xA5'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.228993544', duration='0.00026288', mosi='0x00', miso='0x85'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.229308836', duration='0.000260008', mosi='0x00', miso='0x00'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.22959526', duration='0.000284976', mosi='0x00', miso='0x7F'),
#  SpiFrame(name='"SPI"', ftype='"disable"', start_time='0.229944476', duration='3.99999999e-09', mosi='', miso=''),
#  SpiFrame(name='"SPI"', ftype='"enable"', start_time='0.233607212', duration='3.99999999e-09', mosi='', miso=''),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.233608736', duration='0.000325968', mosi='0x00', miso='0xA5'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.233981584', duration='0.000262884', mosi='0x00', miso='0x85'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.234270884', duration='0.000286012', mosi='0x00', miso='0x00'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.234583312', duration='0.000284884', mosi='0x00', miso='0x7F'),
#  SpiFrame(name='"SPI"', ftype='"disable"', start_time='0.234932428', duration='4.00000002e-09', mosi='', miso=''),
#  SpiFrame(name='"SPI"', ftype='"enable"', start_time='0.238595032', duration='4.00000002e-09', mosi='', miso=''),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.23859656', duration='0.000325904', mosi='0x00', miso='0xA5'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.23896934', duration='0.000262868', mosi='0x00', miso='0x85'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.239258624', duration='0.000285948', mosi='0x00', miso='0x00'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.23957098', duration='0.000258928', mosi='0x00', miso='0x7F'),
#  SpiFrame(name='"SPI"', ftype='"disable"', start_time='0.239920132', duration='4.00000002e-09', mosi='', miso=''),
#  SpiFrame(name='"SPI"', ftype='"enable"', start_time='0.243582548', duration='4.00000002e-09', mosi='', miso=''),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.243584072', duration='0.000299952', mosi='0x00', miso='0xA5'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.243930892', duration='0.000288864', mosi='0x00', miso='0x85'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.244246168', duration='0.000285992', mosi='0x00', miso='0x00'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.244558572', duration='0.000258952', mosi='0x00', miso='0x7F'),
#  SpiFrame(name='"SPI"', ftype='"disable"', start_time='0.244881756', duration='4.00000002e-09', mosi='', miso=''),
#  SpiFrame(name='"SPI"', ftype='"enable"', start_time='0.248570532', duration='3.99999999e-09', mosi='', miso=''),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.248572056', duration='0.000299952', mosi='0x00', miso='0xA5'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.248918884', duration='0.000288724', mosi='0x00', miso='0x85'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.24923402', duration='0.000259996', mosi='0x00', miso='0x00'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.249546432', duration='0.000258968', mosi='0x00', miso='0x7F'),
#  SpiFrame(name='"SPI"', ftype='"disable"', start_time='0.249869632', duration='4.00000002e-09', mosi='', miso=''),
#  SpiFrame(name='"SPI"', ftype='"enable"', start_time='0.253584596', duration='3.99999999e-09', mosi='', miso=''),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.25358612', duration='0.000299984', mosi='0x00', miso='0xA5'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.25393298', duration='0.000288876', mosi='0x00', miso='0x85'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.254248272', duration='0.000260028', mosi='0x00', miso='0x00'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.25453472', duration='0.000284984', mosi='0x00', miso='0x7F'),
#  SpiFrame(name='"SPI"', ftype='"disable"', start_time='0.25488394', duration='4.00000002e-09', mosi='', miso=''),
#  SpiFrame(name='"SPI"', ftype='"enable"', start_time='0.258572424', duration='3.99999999e-09', mosi='', miso=''),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.258573948', duration='0.000325944', mosi='0x00', miso='0xA5'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.258946764', duration='0.000288732', mosi='0x00', miso='0x85'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.259261912', duration='0.00026', mosi='0x00', miso='0x00'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.259548328', duration='0.00028484', mosi='0x00', miso='0x7F'),
#  SpiFrame(name='"SPI"', ftype='"disable"', start_time='0.259897408', duration='3.99999999e-09', mosi='', miso=''),
#  SpiFrame(name='"SPI"', ftype='"enable"', start_time='0.26356072', duration='4.00000005e-09', mosi='', miso=''),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.263562244', duration='0.000325948', mosi='0x00', miso='0xA5'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.263935064', duration='0.000288872', mosi='0x00', miso='0x85'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.264250348', duration='0.000259984', mosi='0x00', miso='0x00'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.264536748', duration='0.00028482', mosi='0x00', miso='0x7F'),
#  SpiFrame(name='"SPI"', ftype='"disable"', start_time='0.264885804', duration='3.99999999e-09', mosi='', miso=''),
#  SpiFrame(name='"SPI"', ftype='"enable"', start_time='0.268548732', duration='3.99999999e-09', mosi='', miso=''),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.26855026', duration='0.000325996', mosi='0x00', miso='0xA5'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.26892314', duration='0.0002629', mosi='0x00', miso='0x85'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.269212456', duration='0.000285868', mosi='0x00', miso='0x00'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.269524744', duration='0.000284844', mosi='0x00', miso='0x7F'),
#  SpiFrame(name='"SPI"', ftype='"disable"', start_time='0.269873828', duration='3.99999999e-09', mosi='', miso=''),
#  SpiFrame(name='"SPI"', ftype='"enable"', start_time='0.273537244', duration='4.00000005e-09', mosi='', miso=''),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.273538768', duration='0.000325824', mosi='0x00', miso='0xA5'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.273911472', duration='0.000262876', mosi='0x00', miso='0x85'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.274200764', duration='0.000285992', mosi='0x00', miso='0x00'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.274513172', duration='0.000258964', mosi='0x00', miso='0x7F'),
#  SpiFrame(name='"SPI"', ftype='"disable"', start_time='0.27486236', duration='4.00000005e-09', mosi='', miso=''),
#  SpiFrame(name='"SPI"', ftype='"enable"', start_time='0.278524988', duration='4.0000001e-09', mosi='', miso=''),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.278526512', duration='0.00029996', mosi='0x00', miso='0xA5'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.278899352', duration='0.000262868', mosi='0x00', miso='0x85'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.279188632', duration='0.00028598', mosi='0x00', miso='0x00'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.279501036', duration='0.000258992', mosi='0x00', miso='0x7F'),
#  SpiFrame(name='"SPI"', ftype='"disable"', start_time='0.279824264', duration='3.99999999e-09', mosi='', miso=''),
#  SpiFrame(name='"SPI"', ftype='"enable"', start_time='0.283513288', duration='3.99999999e-09', mosi='', miso=''),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.283514816', duration='0.000300028', mosi='0x00', miso='0xA5'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.283861732', duration='0.000288932', mosi='0x00', miso='0x85'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.284177088', duration='0.00028604', mosi='0x00', miso='0x00'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.284489548', duration='0.000258976', mosi='0x00', miso='0x7F'),
#  SpiFrame(name='"SPI"', ftype='"disable"', start_time='0.28481276', duration='3.99999999e-09', mosi='', miso=''),
#  SpiFrame(name='"SPI"', ftype='"enable"', start_time='0.288501816', duration='3.99999999e-09', mosi='', miso=''),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.288503344', duration='0.000300032', mosi='0x00', miso='0xA5'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.288850264', duration='0.000288936', mosi='0x00', miso='0x85'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.289165616', duration='0.000260032', mosi='0x00', miso='0x00'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.289452068', duration='0.000285024', mosi='0x00', miso='0x7F'),
#  SpiFrame(name='"SPI"', ftype='"disable"', start_time='0.289801336', duration='4.00000005e-09', mosi='', miso=''),
#  SpiFrame(name='"SPI"', ftype='"enable"', start_time='0.293490792', duration='3.99999999e-09', mosi='', miso=''),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.29349232', duration='0.000325988', mosi='0x00', miso='0xA5'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.293865184', duration='0.00028888', mosi='0x00', miso='0x85'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.29418048', duration='0.00026002', mosi='0x00', miso='0x00'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.29446692', duration='0.000284984', mosi='0x00', miso='0x7F'),
#  SpiFrame(name='"SPI"', ftype='"disable"', start_time='0.294816144', duration='3.99999999e-09', mosi='', miso=''),
#  SpiFrame(name='"SPI"', ftype='"enable"', start_time='0.29847926', duration='3.99999999e-09', mosi='', miso=''),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.298480788', duration='0.000325988', mosi='0x00', miso='0xA5'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.298853652', duration='0.000288904', mosi='0x00', miso='0x85'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.299168976', duration='0.000260052', mosi='0x00', miso='0x00'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.299455448', duration='0.000284936', mosi='0x00', miso='0x7F'),
#  SpiFrame(name='"SPI"', ftype='"disable"', start_time='0.299804624', duration='3.99999999e-09', mosi='', miso=''),
#  SpiFrame(name='"SPI"', ftype='"enable"', start_time='0.30346796', duration='3.99999999e-09', mosi='', miso=''),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.303469484', duration='0.000325976', mosi='0x00', miso='0xA5'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.30384234', duration='0.000262916', mosi='0x00', miso='0x85'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.304131676', duration='0.000286036', mosi='0x00', miso='0x00'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.304444132', duration='0.000285016', mosi='0x00', miso='0x7F'),
#  SpiFrame(name='"SPI"', ftype='"disable"', start_time='0.304793396', duration='4.00000005e-09', mosi='', miso=''),
#  SpiFrame(name='"SPI"', ftype='"enable"', start_time='0.30845654', duration='3.99999999e-09', mosi='', miso=''),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.308458064', duration='0.000325808', mosi='0x00', miso='0xA5'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.308830748', duration='0.000262872', mosi='0x00', miso='0x85'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.309120036', duration='0.000286016', mosi='0x00', miso='0x00'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.309432472', duration='0.000259004', mosi='0x00', miso='0x7F'),
#  SpiFrame(name='"SPI"', ftype='"disable"', start_time='0.309781648', duration='3.99999999e-09', mosi='', miso=''),
#  SpiFrame(name='"SPI"', ftype='"enable"', start_time='0.313445264', duration='3.99999999e-09', mosi='', miso=''),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.313446792', duration='0.000299996', mosi='0x00', miso='0xA5'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.313819524', duration='0.000262916', mosi='0x00', miso='0x85'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.314108856', duration='0.000286004', mosi='0x00', miso='0x00'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.314421276', duration='0.000258988', mosi='0x00', miso='0x7F'),
#  SpiFrame(name='"SPI"', ftype='"disable"', start_time='0.314744492', duration='3.99999999e-09', mosi='', miso=''),
#  SpiFrame(name='"SPI"', ftype='"enable"', start_time='0.31843366', duration='3.99999999e-09', mosi='', miso=''),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.318435184', duration='0.000299984', mosi='0x00', miso='0xA5'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.318782052', duration='0.000288888', mosi='0x00', miso='0x85'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.31909736', duration='0.00028604', mosi='0x00', miso='0x00'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.31940982', duration='0.000258992', mosi='0x00', miso='0x7F'),
#  SpiFrame(name='"SPI"', ftype='"disable"', start_time='0.319733048', duration='4.00000005e-09', mosi='', miso=''),
#  SpiFrame(name='"SPI"', ftype='"enable"', start_time='0.323422164', duration='3.99999999e-09', mosi='', miso=''),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.323423688', duration='0.000299992', mosi='0x00', miso='0xA5'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.323770568', duration='0.000288776', mosi='0x00', miso='0x85'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.324085764', duration='0.000260028', mosi='0x00', miso='0x00'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.324372212', duration='0.000284852', mosi='0x00', miso='0x7F'),
#  SpiFrame(name='"SPI"', ftype='"disable"', start_time='0.324721304', duration='3.99999999e-09', mosi='', miso=''),
#  SpiFrame(name='"SPI"', ftype='"enable"', start_time='0.328411104', duration='3.99999999e-09', mosi='', miso=''),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.328412628', duration='0.000326', mosi='0x00', miso='0xA5'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.328785508', duration='0.000288916', mosi='0x00', miso='0x85'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.329100844', duration='0.000260036', mosi='0x00', miso='0x00'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.3293873', duration='0.000284988', mosi='0x00', miso='0x7F'),
#  SpiFrame(name='"SPI"', ftype='"disable"', start_time='0.329736528', duration='4.00000005e-09', mosi='', miso=''),
#  SpiFrame(name='"SPI"', ftype='"enable"', start_time='0.333399612', duration='4.00000005e-09', mosi='', miso=''),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.333401136', duration='0.00032588', mosi='0x00', miso='0xA5'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.3337739', duration='0.000288924', mosi='0x00', miso='0x85'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.334089244', duration='0.000260028', mosi='0x00', miso='0x00'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.334375688', duration='0.000284984', mosi='0x00', miso='0x7F'),
#  SpiFrame(name='"SPI"', ftype='"disable"', start_time='0.334724912', duration='4.00000005e-09', mosi='', miso=''),
#  SpiFrame(name='"SPI"', ftype='"enable"', start_time='0.338388004', duration='3.99999999e-09', mosi='', miso=''),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.338389528', duration='0.000325968', mosi='0x00', miso='0xA5'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.338762376', duration='0.000262884', mosi='0x00', miso='0x85'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.339051676', duration='0.000286024', mosi='0x00', miso='0x00'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.33936412', duration='0.000285', mosi='0x00', miso='0x7F'),
#  SpiFrame(name='"SPI"', ftype='"disable"', start_time='0.339713364', duration='3.99999999e-09', mosi='', miso=''),
#  SpiFrame(name='"SPI"', ftype='"enable"', start_time='0.343376436', duration='3.99999999e-09', mosi='', miso=''),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.343377964', duration='0.000325984', mosi='0x00', miso='0xA5'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.343750836', duration='0.000262912', mosi='0x00', miso='0x85'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.344040164', duration='0.000285868', mosi='0x00', miso='0x00'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.344352452', duration='0.000258996', mosi='0x00', miso='0x7F'),
# ...
#  SpiFrame(name='"SPI"', ftype='"enable"', start_time='0.722513396', duration='3.99999999e-09', mosi='', miso=''),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.722514924', duration='0.000326', mosi='0x00', miso='0xA5'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.722887808', duration='0.000288844', mosi='0x00', miso='0x85'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.723203072', duration='0.000260024', mosi='0x00', miso='0x00'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.723489516', duration='0.000285', mosi='0x00', miso='0x7F'),
#  SpiFrame(name='"SPI"', ftype='"disable"', start_time='0.72383876', duration='3.99999999e-09', mosi='', miso=''),
#  SpiFrame(name='"SPI"', ftype='"enable"', start_time='0.727502192', duration='3.99999999e-09', mosi='', miso=''),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.72750372', duration='0.000326004', mosi='0x00', miso='0xA5'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.727876608', duration='0.000262888', mosi='0x00', miso='0x85'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.728191764', duration='0.00026004', mosi='0x00', miso='0x00'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.728478224', duration='0.000284992', mosi='0x00', miso='0x7F'),
#  SpiFrame(name='"SPI"', ftype='"disable"', start_time='0.72882746', duration='3.99999999e-09', mosi='', miso=''),
#  SpiFrame(name='"SPI"', ftype='"enable"', start_time='0.73249074', duration='3.99999999e-09', mosi='', miso=''),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.732492264', duration='0.000325972', mosi='0x00', miso='0xA5'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.73286512', duration='0.000262912', mosi='0x00', miso='0x85'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.733154448', duration='0.000285956', mosi='0x00', miso='0x00'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.73346682', duration='0.000258996', mosi='0x00', miso='0x7F'),
#  SpiFrame(name='"SPI"', ftype='"disable"', start_time='0.733816056', duration='3.99999999e-09', mosi='', miso=''),
#  SpiFrame(name='"SPI"', ftype='"enable"', start_time='0.7374793', duration='3.99999999e-09', mosi='', miso=''),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.737480824', duration='0.000325964', mosi='0x00', miso='0xA5'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.73785366', duration='0.000262904', mosi='0x00', miso='0x85'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.738142984', duration='0.000286032', mosi='0x00', miso='0x00'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.738455432', duration='0.000258992', mosi='0x00', miso='0x7F'),
#  SpiFrame(name='"SPI"', ftype='"disable"', start_time='0.738778668', duration='3.99999999e-09', mosi='', miso=''),
#  SpiFrame(name='"SPI"', ftype='"enable"', start_time='0.74246796', duration='3.99999999e-09', mosi='', miso=''),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.742469484', duration='0.000299988', mosi='0x00', miso='0xA5'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.742816352', duration='0.000288916', mosi='0x00', miso='0x85'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.743131688', duration='0.00028604', mosi='0x00', miso='0x00'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.743444148', duration='0.000258996', mosi='0x00', miso='0x7F'),
#  SpiFrame(name='"SPI"', ftype='"disable"', start_time='0.743767396', duration='3.99999999e-09', mosi='', miso=''),
#  SpiFrame(name='"SPI"', ftype='"enable"', start_time='0.747456504', duration='3.99999999e-09', mosi='', miso=''),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.747458032', duration='0.000299972', mosi='0x00', miso='0xA5'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.747804884', duration='0.000288896', mosi='0x00', miso='0x85'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.748120196', duration='0.000264344', mosi='0x00', miso='0x00'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.748436952', duration='0.000258968', mosi='0x00', miso='0x7F'),
#  SpiFrame(name='"SPI"', ftype='"disable"', start_time='0.74876016', duration='3.99999999e-09', mosi='', miso=''),
#  SpiFrame(name='"SPI"', ftype='"enable"', start_time='0.7524446', duration='3.99999999e-09', mosi='', miso=''),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.752446128', duration='0.000325984', mosi='0x00', miso='0xA5'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.752818992', duration='0.000288896', mosi='0x00', miso='0x85'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.753134308', duration='0.00026002', mosi='0x00', miso='0x00'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.753420748', duration='0.000284984', mosi='0x00', miso='0x7F'),
#  SpiFrame(name='"SPI"', ftype='"disable"', start_time='0.753769968', duration='3.99999999e-09', mosi='', miso=''),
#  SpiFrame(name='"SPI"', ftype='"enable"', start_time='0.757432772', duration='3.99999999e-09', mosi='', miso=''),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.7574343', duration='0.000325964', mosi='0x00', miso='0xA5'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.75780714', duration='0.000288884', mosi='0x00', miso='0x85'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.75812244', duration='0.000260008', mosi='0x00', miso='0x00'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.758408864', duration='0.000284952', mosi='0x00', miso='0x7F'),
#  SpiFrame(name='"SPI"', ftype='"disable"', start_time='0.758758048', duration='3.99999999e-09', mosi='', miso=''),
#  SpiFrame(name='"SPI"', ftype='"enable"', start_time='0.762421088', duration='3.99999999e-09', mosi='', miso=''),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.762422612', duration='0.00032598', mosi='0x00', miso='0xA5'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.762795472', duration='0.000262896', mosi='0x00', miso='0x85'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.763110632', duration='0.000259996', mosi='0x00', miso='0x00'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.763397048', duration='0.000284988', mosi='0x00', miso='0x7F'),
#  SpiFrame(name='"SPI"', ftype='"disable"', start_time='0.763746272', duration='3.99999999e-09', mosi='', miso=''),
#  SpiFrame(name='"SPI"', ftype='"enable"', start_time='0.76740892', duration='3.99999999e-09', mosi='', miso=''),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.767410444', duration='0.000325824', mosi='0x00', miso='0xA5'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.767783152', duration='0.000262884', mosi='0x00', miso='0x85'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.768072452', duration='0.00028598', mosi='0x00', miso='0x00'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.768384848', duration='0.00028482', mosi='0x00', miso='0x7F'),
#  SpiFrame(name='"SPI"', ftype='"disable"', start_time='0.768733896', duration='3.99999999e-09', mosi='', miso=''),
#  SpiFrame(name='"SPI"', ftype='"enable"', start_time='0.772396948', duration='3.99999999e-09', mosi='', miso=''),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.772398472', duration='0.000325968', mosi='0x00', miso='0xA5'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.772771308', duration='0.000262872', mosi='0x00', miso='0x85'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.773060596', duration='0.000285828', mosi='0x00', miso='0x00'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.77337284', duration='0.000259004', mosi='0x00', miso='0x7F'),
#  SpiFrame(name='"SPI"', ftype='"disable"', start_time='0.773696084', duration='3.99999999e-09', mosi='', miso=''),
#  SpiFrame(name='"SPI"', ftype='"enable"', start_time='0.777385308', duration='3.99999999e-09', mosi='', miso=''),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.777386832', duration='0.000300024', mosi='0x00', miso='0xA5'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.777733744', duration='0.000288912', mosi='0x00', miso='0x85'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.778049072', duration='0.000286008', mosi='0x00', miso='0x00'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.778361496', duration='0.000258992', mosi='0x00', miso='0x7F'),
#  SpiFrame(name='"SPI"', ftype='"disable"', start_time='0.778684716', duration='3.99999999e-09', mosi='', miso=''),
#  SpiFrame(name='"SPI"', ftype='"enable"', start_time='0.782373752', duration='3.99999999e-09', mosi='', miso=''),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.78237528', duration='0.000299964', mosi='0x00', miso='0xA5'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.782722124', duration='0.000288884', mosi='0x00', miso='0x85'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.78303742', duration='0.00026004', mosi='0x00', miso='0x00'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.783349888', duration='0.00025902', mosi='0x00', miso='0x7F'),
#  SpiFrame(name='"SPI"', ftype='"disable"', start_time='0.783673148', duration='3.99999999e-09', mosi='', miso=''),
#  SpiFrame(name='"SPI"', ftype='"enable"', start_time='0.787362164', duration='3.99999999e-09', mosi='', miso=''),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.787363692', duration='0.000325988', mosi='0x00', miso='0xA5'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.787736564', duration='0.000288852', mosi='0x00', miso='0x85'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.788051836', duration='0.00026004', mosi='0x00', miso='0x00'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.788338296', duration='0.000284972', mosi='0x00', miso='0x7F'),
#  SpiFrame(name='"SPI"', ftype='"disable"', start_time='0.788687504', duration='3.99999999e-09', mosi='', miso=''),
#  SpiFrame(name='"SPI"', ftype='"enable"', start_time='0.79235056', duration='3.99999999e-09', mosi='', miso=''),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.792352088', duration='0.000325952', mosi='0x00', miso='0xA5'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.79272492', duration='0.000288884', mosi='0x00', miso='0x85'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.79304022', duration='0.000260008', mosi='0x00', miso='0x00'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.793326644', duration='0.000284964', mosi='0x00', miso='0x7F'),
#  SpiFrame(name='"SPI"', ftype='"disable"', start_time='0.793675848', duration='3.99999999e-09', mosi='', miso=''),
#  SpiFrame(name='"SPI"', ftype='"enable"', start_time='0.7973388', duration='3.99999999e-09', mosi='', miso=''),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.797340328', duration='0.000325984', mosi='0x00', miso='0xA5'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.797713192', duration='0.000262912', mosi='0x00', miso='0x85'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.798028444', duration='0.000260052', mosi='0x00', miso='0x00'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.79831492', duration='0.000285004', mosi='0x00', miso='0x7F'),
#  SpiFrame(name='"SPI"', ftype='"disable"', start_time='0.798664164', duration='3.99999999e-09', mosi='', miso=''),
#  SpiFrame(name='"SPI"', ftype='"enable"', start_time='0.80232724', duration='3.99999999e-09', mosi='', miso=''),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.802328764', duration='0.000325924', mosi='0x00', miso='0xA5'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.802701564', duration='0.000262872', mosi='0x00', miso='0x85'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.802990852', duration='0.00028584', mosi='0x00', miso='0x00'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.803303108', duration='0.000284968', mosi='0x00', miso='0x7F'),
#  SpiFrame(name='"SPI"', ftype='"disable"', start_time='0.8036523', duration='3.99999999e-09', mosi='', miso=''),
#  SpiFrame(name='"SPI"', ftype='"enable"', start_time='0.807315496', duration='3.99999999e-09', mosi='', miso=''),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.807317024', duration='0.00032598', mosi='0x00', miso='0xA5'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.807689884', duration='0.000262884', mosi='0x00', miso='0x85'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.807979184', duration='0.000286004', mosi='0x00', miso='0x00'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.808291604', duration='0.000258976', mosi='0x00', miso='0x7F'),
#  SpiFrame(name='"SPI"', ftype='"disable"', start_time='0.808614816', duration='4.0000001e-09', mosi='', miso=''),
#  SpiFrame(name='"SPI"', ftype='"enable"', start_time='0.812303404', duration='3.99999999e-09', mosi='', miso=''),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.812304928', duration='0.00029998', mosi='0x00', miso='0xA5'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.812651784', duration='0.00028888', mosi='0x00', miso='0x85'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.81296708', duration='0.000285844', mosi='0x00', miso='0x00'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.81327934', duration='0.000258968', mosi='0x00', miso='0x7F'),
#  SpiFrame(name='"SPI"', ftype='"disable"', start_time='0.813602544', duration='3.99999999e-09', mosi='', miso=''),
#  SpiFrame(name='"SPI"', ftype='"enable"', start_time='0.817291584', duration='3.99999999e-09', mosi='', miso=''),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.817293112', duration='0.000299956', mosi='0x00', miso='0xA5'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.817639952', duration='0.000288888', mosi='0x00', miso='0x85'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.817955252', duration='0.000259992', mosi='0x00', miso='0x00'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.818267656', duration='0.000259', mosi='0x00', miso='0x7F'),
#  SpiFrame(name='"SPI"', ftype='"disable"', start_time='0.818590896', duration='3.99999999e-09', mosi='', miso=''),
#  SpiFrame(name='"SPI"', ftype='"enable"', start_time='0.822305832', duration='3.99999999e-09', mosi='', miso=''),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.822307356', duration='0.000299988', mosi='0x00', miso='0xA5'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.82265422', duration='0.000288908', mosi='0x00', miso='0x85'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.822969548', duration='0.00026002', mosi='0x00', miso='0x00'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.823255984', duration='0.00028482', mosi='0x00', miso='0x7F'),
#  SpiFrame(name='"SPI"', ftype='"disable"', start_time='0.823605036', duration='3.99999999e-09', mosi='', miso=''),
#  SpiFrame(name='"SPI"', ftype='"enable"', start_time='0.827268048', duration='3.99999999e-09', mosi='', miso=''),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.827269572', duration='0.000325776', mosi='0x00', miso='0xA5'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.82764222', duration='0.000288724', mosi='0x00', miso='0x85'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.827957364', duration='0.000260004', mosi='0x00', miso='0x00'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.828243784', duration='0.000285', mosi='0x00', miso='0x7F'),
#  SpiFrame(name='"SPI"', ftype='"disable"', start_time='0.828593024', duration='3.99999999e-09', mosi='', miso=''),
#  SpiFrame(name='"SPI"', ftype='"enable"', start_time='0.832256528', duration='3.99999999e-09', mosi='', miso=''),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.832258056', duration='0.000325836', mosi='0x00', miso='0xA5'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.832630772', duration='0.000262892', mosi='0x00', miso='0x85'),
#  SpiFrame(name='"SPI"', ftype='"result"', start_time='0.83294608', duration='0.000260004', mosi='0x00', miso='0x00'),
#  ...]

# %%
data = pack_4(frames)

# %%
set(len(d.split()) for d in data.values())  # Sanity check: Data only contains batches of 4 bytes
# Out:
# {4}

# %%
set(data.values())
# Out:
# {'0x5A 0x08 0x10 0x00',
#  '0x5A 0x08 0x10 0x10',
#  '0x5A 0x08 0x10 0x20',
#  '0x5A 0x08 0x10 0x40',
#  '0x5A 0x08 0x10 0x60',
#  '0x5A 0x08 0x10 0x80',
#  '0x5A 0x08 0x10 0x90',
#  '0x5A 0x08 0x10 0xA0',
#  '0x5A 0x08 0x10 0xC0',
#  '0x5A 0x08 0x10 0xE0',
#  '0x5A 0x08 0x90 0x00',
#  '0x5A 0x08 0xE0 0x10',
#  '0x5A 0x08 0xE0 0x20',
#  '0x5A 0x08 0xE0 0x60',
#  '0x5A 0x08 0xE0 0x90',
#  '0x5A 0x08 0xE0 0xA0',
#  '0x5A 0x08 0xE0 0xE0',
#  '0xA5 0x85 0x00 0x7F',
#  '0xA5 0x85 0x10 0x6F'}

# %%
count_unique_frames(data)
# Out:
# Counter({'0xA5 0x85 0x10 0x6F': 2428,
#          '0xA5 0x85 0x00 0x7F': 639,
#          '0x5A 0x08 0xE0 0x20': 1,
#          '0x5A 0x08 0xE0 0xA0': 1,
#          '0x5A 0x08 0xE0 0x60': 1,
#          '0x5A 0x08 0xE0 0xE0': 1,
#          '0x5A 0x08 0xE0 0x10': 1,
#          '0x5A 0x08 0xE0 0x90': 1,
#          '0x5A 0x08 0x10 0x00': 1,
#          '0x5A 0x08 0x10 0x80': 1,
#          '0x5A 0x08 0x10 0x40': 1,
#          '0x5A 0x08 0x10 0xC0': 1,
#          '0x5A 0x08 0x10 0x20': 1,
#          '0x5A 0x08 0x10 0xA0': 1,
#          '0x5A 0x08 0x10 0x60': 1,
#          '0x5A 0x08 0x10 0xE0': 1,
#          '0x5A 0x08 0x10 0x10': 1,
#          '0x5A 0x08 0x10 0x90': 1,
#          '0x5A 0x08 0x90 0x00': 1})

# %%
for start_time, miso in data.items():
    if miso.startswith("0x5A"):
        print(f"{start_time}\t{miso}")
# Out:
# 2.62008163	0x5A 0x08 0xE0 0x20
# 3.17880782	0x5A 0x08 0xE0 0xA0
# 3.73790791	0x5A 0x08 0xE0 0x60
# 4.29666157	0x5A 0x08 0xE0 0xE0
# 4.85538271	0x5A 0x08 0xE0 0x10
# 5.41407471	0x5A 0x08 0xE0 0x90
# 5.97280619	0x5A 0x08 0x10 0x00
# 6.53153903	0x5A 0x08 0x10 0x80
# 7.09523752	0x5A 0x08 0x10 0x40
# 7.65396234	0x5A 0x08 0x10 0xC0
# 8.21271848	0x5A 0x08 0x10 0x20
# 8.77155664	0x5A 0x08 0x10 0xA0
# 9.33030042	0x5A 0x08 0x10 0x60
# 9.88902517	0x5A 0x08 0x10 0xE0
# 10.4477285	0x5A 0x08 0x10 0x10
# 11.0064762	0x5A 0x08 0x10 0x90
# 11.6547707	0x5A 0x08 0x90 0x00

# %%
print_reversed([miso for miso in data.values() if miso.startswith("0x5A")])
# Out:
# original data		reversed decimal	reversed hexadecimal	reversed binary
# 0x5A 0x08 0xE0 0x20	90 16 7 4		0x5A 0x10 0x07 0x04	01011010 00010000 00000111 00000100
# 0x5A 0x08 0xE0 0xA0	90 16 7 5		0x5A 0x10 0x07 0x05	01011010 00010000 00000111 00000101
# 0x5A 0x08 0xE0 0x60	90 16 7 6		0x5A 0x10 0x07 0x06	01011010 00010000 00000111 00000110
# 0x5A 0x08 0xE0 0xE0	90 16 7 7		0x5A 0x10 0x07 0x07	01011010 00010000 00000111 00000111
# 0x5A 0x08 0xE0 0x10	90 16 7 8		0x5A 0x10 0x07 0x08	01011010 00010000 00000111 00001000
# 0x5A 0x08 0xE0 0x90	90 16 7 9		0x5A 0x10 0x07 0x09	01011010 00010000 00000111 00001001
# 0x5A 0x08 0x10 0x00	90 16 8 0		0x5A 0x10 0x08 0x00	01011010 00010000 00001000 00000000
# 0x5A 0x08 0x10 0x80	90 16 8 1		0x5A 0x10 0x08 0x01	01011010 00010000 00001000 00000001
# 0x5A 0x08 0x10 0x40	90 16 8 2		0x5A 0x10 0x08 0x02	01011010 00010000 00001000 00000010
# 0x5A 0x08 0x10 0xC0	90 16 8 3		0x5A 0x10 0x08 0x03	01011010 00010000 00001000 00000011
# 0x5A 0x08 0x10 0x20	90 16 8 4		0x5A 0x10 0x08 0x04	01011010 00010000 00001000 00000100
# 0x5A 0x08 0x10 0xA0	90 16 8 5		0x5A 0x10 0x08 0x05	01011010 00010000 00001000 00000101
# 0x5A 0x08 0x10 0x60	90 16 8 6		0x5A 0x10 0x08 0x06	01011010 00010000 00001000 00000110
# 0x5A 0x08 0x10 0xE0	90 16 8 7		0x5A 0x10 0x08 0x07	01011010 00010000 00001000 00000111
# 0x5A 0x08 0x10 0x10	90 16 8 8		0x5A 0x10 0x08 0x08	01011010 00010000 00001000 00001000
# 0x5A 0x08 0x10 0x90	90 16 8 9		0x5A 0x10 0x08 0x09	01011010 00010000 00001000 00001001
# 0x5A 0x08 0x90 0x00	90 16 9 0		0x5A 0x10 0x09 0x00	01011010 00010000 00001001 00000000

# %%
with open("data/button-2-drive-down.csv", "r", encoding="utf-8") as f:
    lines_down = f.read().split()

frames_down = parse_frames(lines_down)
data_down = pack_4(frames_down)

set(len(d.split()) for d in data_down.values())  # Sanity check: Data only contains batches of 4 bytes
# Out:
# {4}

# %%
count_unique_frames(data_down)
# Out:
# Counter({'0xA5 0x85 0x10 0x6F': 1329,
#          '0xA5 0x85 0x00 0x7F': 326,
#          '0x5A 0x08 0x90 0xE0': 1,
#          '0x5A 0x08 0x90 0x60': 1,
#          '0x5A 0x08 0x90 0xA0': 1,
#          '0x5A 0x08 0x90 0x20': 1,
#          '0x5A 0x08 0x90 0xC0': 1,
#          '0x5A 0x08 0x90 0x40': 1,
#          '0x5A 0x08 0x90 0x80': 1,
#          '0x5A 0x08 0x90 0x00': 1,
#          '0x00 0x00 0x00 0x00': 1,
#          '0x00 0x80 0x00 0x07': 1})

# %%
for start_time, miso in data_down.items():
    if miso.startswith("0x5A"):
        print(f"{start_time}\t{miso}")
# Out:
# 1.27949046	0x5A 0x08 0x90 0xE0
# 2.73107526	0x5A 0x08 0x90 0x60
# 3.37939679	0x5A 0x08 0x90 0xA0
# 3.93826862	0x5A 0x08 0x90 0x20
# 4.49684859	0x5A 0x08 0x90 0xC0
# 5.05548906	0x5A 0x08 0x90 0x40
# 5.61413758	0x5A 0x08 0x90 0x80
# 6.20252918	0x5A 0x08 0x90 0x00

# %%
print_reversed([miso for miso in data_down.values() if miso.startswith("0x5A")])
# Out:
# original data		reversed decimal	reversed hexadecimal	reversed binary
# 0x5A 0x08 0x90 0xE0	90 16 9 7		0x5A 0x10 0x09 0x07	01011010 00010000 00001001 00000111
# 0x5A 0x08 0x90 0x60	90 16 9 6		0x5A 0x10 0x09 0x06	01011010 00010000 00001001 00000110
# 0x5A 0x08 0x90 0xA0	90 16 9 5		0x5A 0x10 0x09 0x05	01011010 00010000 00001001 00000101
# 0x5A 0x08 0x90 0x20	90 16 9 4		0x5A 0x10 0x09 0x04	01011010 00010000 00001001 00000100
# 0x5A 0x08 0x90 0xC0	90 16 9 3		0x5A 0x10 0x09 0x03	01011010 00010000 00001001 00000011
# 0x5A 0x08 0x90 0x40	90 16 9 2		0x5A 0x10 0x09 0x02	01011010 00010000 00001001 00000010
# 0x5A 0x08 0x90 0x80	90 16 9 1		0x5A 0x10 0x09 0x01	01011010 00010000 00001001 00000001
# 0x5A 0x08 0x90 0x00	90 16 9 0		0x5A 0x10 0x09 0x00	01011010 00010000 00001001 00000000

# %% [markdown]
# **Note: Up until know I've had the logic analyzer in the wrong setting (MSB first, while LSB first would have been the write setting). That's why the following data might look a bit different.**
#
# ### Analyzing Button-Codes
#
# This is the order of the buttons on the control-panel from left to right:
#
# 1. Button 1
# 2. Button 2
# 3. Button 3
# 4. Button 4
# 5. Button S
# 6. Button UP
# 7. Button DOWN
#
# Their is kind of a binary pattern in the encoding of the button-data. However the order is switched up from the representation on the control-panel:

# %%
print_data_table([
    "0xA5 0xA1 0x00 0xFE",  # Idle
    "0xA5 0xA1 0x02 0xFC",  # Button 4
    "0xA5 0xA1 0x04 0xFA",  # Button 1
    "0xA5 0xA1 0x08 0xF6",  # Button 2
    "0xA5 0xA1 0x10 0xEE",  # Button 3
    "0xA5 0xA1 0x20 0xDE",  # Button S
    "0xA5 0xA1 0x40 0xBE",  # Button UP
    "0xA5 0xA1 0x80 0x7E",  # Button DOWN
])
# Out:
# original data		binary encoding				decimal encoding
# 0xA5 0xA1 0x00 0xFE	10100101 10100001 00000000 11111110	165 161 0 254
# 0xA5 0xA1 0x02 0xFC	10100101 10100001 00000010 11111100	165 161 2 252
# 0xA5 0xA1 0x04 0xFA	10100101 10100001 00000100 11111010	165 161 4 250
# 0xA5 0xA1 0x08 0xF6	10100101 10100001 00001000 11110110	165 161 8 246
# 0xA5 0xA1 0x10 0xEE	10100101 10100001 00010000 11101110	165 161 16 238
# 0xA5 0xA1 0x20 0xDE	10100101 10100001 00100000 11011110	165 161 32 222
# 0xA5 0xA1 0x40 0xBE	10100101 10100001 01000000 10111110	165 161 64 190
# 0xA5 0xA1 0x80 0x7E	10100101 10100001 10000000 01111110	165 161 128 126

# %% [markdown]
# ## Analyzing a longer recording
#
# Driving to standing position and back to sitting position

# %%
with open("data/drive-to-2-drive-to-1.csv", "r", encoding="utf-8") as f:
    lines_up_down = f.read().split()

frames_up_down = parse_frames(lines_up_down)
data_up_down = pack_4(frames_up_down)

set(len(d.split()) for d in data_up_down.values())  # Sanity check: Data only contains batches of 4 bytes
# Out:
# {4}

# %%
count_unique_frames(data_up_down)
# Out:
# Counter({'0xA5 0xA1 0x00 0xFE': 4599,
#          '0xA5 0xA1 0x04 0xFA': 3332,
#          '0xA5 0xA1 0x08 0xF6': 2503,
#          '0x5A 0x10 0x07 0x03': 2,
#          '0x5A 0x10 0x07 0x04': 2,
#          '0x5A 0x10 0x07 0x05': 2,
#          '0x5A 0x10 0x07 0x06': 2,
#          '0x5A 0x10 0x07 0x07': 2,
#          '0x5A 0x10 0x07 0x08': 2,
#          '0x5A 0x10 0x07 0x09': 2,
#          '0x5A 0x10 0x08 0x00': 2,
#          '0x5A 0x10 0x08 0x01': 2,
#          '0x5A 0x10 0x08 0x02': 2,
#          '0x5A 0x10 0x08 0x03': 2,
#          '0x5A 0x10 0x08 0x04': 2,
#          '0x5A 0x10 0x08 0x05': 2,
#          '0x5A 0x10 0x08 0x06': 2,
#          '0x5A 0x10 0x08 0x07': 2,
#          '0x5A 0x10 0x08 0x08': 2,
#          '0x5A 0x10 0x08 0x09': 2,
#          '0x5A 0x10 0x09 0x00': 1,
#          '0x5A 0x10 0x10 0x10': 1})

# %%
for start_time, miso in data_up_down.items():
    if miso.startswith("0x5A"):
        print(f"{start_time}\t{miso}")
# Out:
# 1.11718302	0x5A 0x10 0x07 0x03
# 2.82843954	0x5A 0x10 0x07 0x04
# 3.3871538	0x5A 0x10 0x07 0x05
# 3.94628183	0x5A 0x10 0x07 0x06
# 4.50505025	0x5A 0x10 0x07 0x07
# 5.06380986	0x5A 0x10 0x07 0x08
# 5.62260277	0x5A 0x10 0x07 0x09
# 6.18140317	0x5A 0x10 0x08 0x00
# 6.7402282	0x5A 0x10 0x08 0x01
# 7.29903691	0x5A 0x10 0x08 0x02
# 7.85784968	0x5A 0x10 0x08 0x03
# 8.41669991	0x5A 0x10 0x08 0x04
# 8.97550896	0x5A 0x10 0x08 0x05
# 9.53435949	0x5A 0x10 0x08 0x06
# 10.093176	0x5A 0x10 0x08 0x07
# 10.6569637	0x5A 0x10 0x08 0x08
# 11.2157609	0x5A 0x10 0x08 0x09
# 11.864031	0x5A 0x10 0x09 0x00
# 17.2727823	0x5A 0x10 0x08 0x09
# 17.8316946	0x5A 0x10 0x08 0x08
# 18.3908749	0x5A 0x10 0x08 0x07
# 18.9497777	0x5A 0x10 0x08 0x06
# 19.5086127	0x5A 0x10 0x08 0x05
# 20.0674673	0x5A 0x10 0x08 0x04
# 20.6263135	0x5A 0x10 0x08 0x03
# 21.1851855	0x5A 0x10 0x08 0x02
# 21.7440361	0x5A 0x10 0x08 0x01
# 22.3028829	0x5A 0x10 0x08 0x00
# 22.8617178	0x5A 0x10 0x07 0x09
# 23.4205638	0x5A 0x10 0x07 0x08
# 23.9794343	0x5A 0x10 0x07 0x07
# 24.5432703	0x5A 0x10 0x07 0x06
# 25.1021338	0x5A 0x10 0x07 0x05
# 25.6610839	0x5A 0x10 0x07 0x04
# 30.3117568	0x5A 0x10 0x07 0x03
# 53.2189864	0x5A 0x10 0x10 0x10

# %%
print_data_table([miso for miso in data_up_down.values() if miso.startswith("0x5A")])
# Out:
# original data		binary encoding				decimal encoding
# 0x5A 0x10 0x07 0x03	01011010 00010000 00000111 00000011	90 16 7 3
# 0x5A 0x10 0x07 0x04	01011010 00010000 00000111 00000100	90 16 7 4
# 0x5A 0x10 0x07 0x05	01011010 00010000 00000111 00000101	90 16 7 5
# 0x5A 0x10 0x07 0x06	01011010 00010000 00000111 00000110	90 16 7 6
# 0x5A 0x10 0x07 0x07	01011010 00010000 00000111 00000111	90 16 7 7
# 0x5A 0x10 0x07 0x08	01011010 00010000 00000111 00001000	90 16 7 8
# 0x5A 0x10 0x07 0x09	01011010 00010000 00000111 00001001	90 16 7 9
# 0x5A 0x10 0x08 0x00	01011010 00010000 00001000 00000000	90 16 8 0
# 0x5A 0x10 0x08 0x01	01011010 00010000 00001000 00000001	90 16 8 1
# 0x5A 0x10 0x08 0x02	01011010 00010000 00001000 00000010	90 16 8 2
# 0x5A 0x10 0x08 0x03	01011010 00010000 00001000 00000011	90 16 8 3
# 0x5A 0x10 0x08 0x04	01011010 00010000 00001000 00000100	90 16 8 4
# 0x5A 0x10 0x08 0x05	01011010 00010000 00001000 00000101	90 16 8 5
# 0x5A 0x10 0x08 0x06	01011010 00010000 00001000 00000110	90 16 8 6
# 0x5A 0x10 0x08 0x07	01011010 00010000 00001000 00000111	90 16 8 7
# 0x5A 0x10 0x08 0x08	01011010 00010000 00001000 00001000	90 16 8 8
# 0x5A 0x10 0x08 0x09	01011010 00010000 00001000 00001001	90 16 8 9
# 0x5A 0x10 0x09 0x00	01011010 00010000 00001001 00000000	90 16 9 0
# 0x5A 0x10 0x08 0x09	01011010 00010000 00001000 00001001	90 16 8 9
# 0x5A 0x10 0x08 0x08	01011010 00010000 00001000 00001000	90 16 8 8
# 0x5A 0x10 0x08 0x07	01011010 00010000 00001000 00000111	90 16 8 7
# 0x5A 0x10 0x08 0x06	01011010 00010000 00001000 00000110	90 16 8 6
# 0x5A 0x10 0x08 0x05	01011010 00010000 00001000 00000101	90 16 8 5
# 0x5A 0x10 0x08 0x04	01011010 00010000 00001000 00000100	90 16 8 4
# 0x5A 0x10 0x08 0x03	01011010 00010000 00001000 00000011	90 16 8 3
# 0x5A 0x10 0x08 0x02	01011010 00010000 00001000 00000010	90 16 8 2
# 0x5A 0x10 0x08 0x01	01011010 00010000 00001000 00000001	90 16 8 1
# 0x5A 0x10 0x08 0x00	01011010 00010000 00001000 00000000	90 16 8 0
# 0x5A 0x10 0x07 0x09	01011010 00010000 00000111 00001001	90 16 7 9
# 0x5A 0x10 0x07 0x08	01011010 00010000 00000111 00001000	90 16 7 8
# 0x5A 0x10 0x07 0x07	01011010 00010000 00000111 00000111	90 16 7 7
# 0x5A 0x10 0x07 0x06	01011010 00010000 00000111 00000110	90 16 7 6
# 0x5A 0x10 0x07 0x05	01011010 00010000 00000111 00000101	90 16 7 5
# 0x5A 0x10 0x07 0x04	01011010 00010000 00000111 00000100	90 16 7 4
# 0x5A 0x10 0x07 0x03	01011010 00010000 00000111 00000011	90 16 7 3
# 0x5A 0x10 0x10 0x10	01011010 00010000 00010000 00010000	90 16 16 16

# %% [markdown]
# No big surprises here. Only the "go to sleep" frame
